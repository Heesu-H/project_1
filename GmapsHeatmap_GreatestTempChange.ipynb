# %%
# Dependencies and Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import Data from dataset
df_land_temp = pd.read_csv("data_sets/GlobalLandTemperaturesByCountry.csv")

# %%
df_land_temp
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...          ...
# 577457  Zimbabwe
# 577458  Zimbabwe
# 577459  Zimbabwe
# 577460  Zimbabwe
# 577461  Zimbabwe
#
# [577462 rows x 4 columns]

# %%
splited_land_ser = df_land_temp['dt'].str.split('-').str[0]
splited_land_ser
# Out:
# 0         1743
# 1         1743
# 2         1744
# 3         1744
# 4         1744
#           ...
# 577457    2013
# 577458    2013
# 577459    2013
# 577460    2013
# 577461    2013
# Name: dt, Length: 577462, dtype: object

# %%
df_land_temp["year"] = splited_land_ser.astype("int64")

# %%
df_land_temp
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country  year
# 0          Åland  1743
# 1          Åland  1743
# 2          Åland  1744
# 3          Åland  1744
# 4          Åland  1744
# ...          ...   ...
# 577457  Zimbabwe  2013
# 577458  Zimbabwe  2013
# 577459  Zimbabwe  2013
# 577460  Zimbabwe  2013
# 577461  Zimbabwe  2013
#
# [577462 rows x 5 columns]

# %%
df_land_temp_1963 = df_land_temp.loc[(df_land_temp["year"] > 1962) & (df_land_temp["year"] < 2016),:].copy()
df_land_temp_1963
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2630    1963-01-01              -6.288                          0.981
# 2631    1963-02-01              -8.085                          0.587
# 2632    1963-03-01              -5.510                          0.558
# 2633    1963-04-01               1.452                          0.743
# 2634    1963-05-01               9.560                          0.433
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country  year
# 2630       Åland  1963
# 2631       Åland  1963
# 2632       Åland  1963
# 2633       Åland  1963
# 2634       Åland  1963
# ...          ...   ...
# 577457  Zimbabwe  2013
# 577458  Zimbabwe  2013
# 577459  Zimbabwe  2013
# 577460  Zimbabwe  2013
# 577461  Zimbabwe  2013
#
# [147987 rows x 5 columns]

# %%
df_land_temp_1963
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2630    1963-01-01              -6.288                          0.981
# 2631    1963-02-01              -8.085                          0.587
# 2632    1963-03-01              -5.510                          0.558
# 2633    1963-04-01               1.452                          0.743
# 2634    1963-05-01               9.560                          0.433
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country  year
# 2630       Åland  1963
# 2631       Åland  1963
# 2632       Åland  1963
# 2633       Åland  1963
# 2634       Åland  1963
# ...          ...   ...
# 577457  Zimbabwe  2013
# 577458  Zimbabwe  2013
# 577459  Zimbabwe  2013
# 577460  Zimbabwe  2013
# 577461  Zimbabwe  2013
#
# [147987 rows x 5 columns]
