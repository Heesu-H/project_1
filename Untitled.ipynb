# %%
import numpy as np
import pandas as pd
from scipy.stats import linregress
from matplotlib import pyplot as plt
import random

# %%
Series_name=[]
df=pd.read_csv('./data_sets/climate_change_data.csv')
df
# Out:
#       Country code      Country name     Series code  \
# 0              ABW             Aruba  AG.LND.EL5M.ZS
# 1              ADO           Andorra  AG.LND.EL5M.ZS
# 2              AFG       Afghanistan  AG.LND.EL5M.ZS
# 3              AGO            Angola  AG.LND.EL5M.ZS
# 4              ALB           Albania  AG.LND.EL5M.ZS
# ...            ...               ...             ...
# 13507          YEM       Yemen, Rep.     SP.URB.TOTL
# 13508          ZAF      South Africa     SP.URB.TOTL
# 13509          ZAR  Congo, Dem. Rep.     SP.URB.TOTL
# 13510          ZMB            Zambia     SP.URB.TOTL
# 13511          ZWE          Zimbabwe     SP.URB.TOTL
#
#                                Series name SCALE Decimals         1990  \
# 0      Land area below 5m (% of land area)     0        1        29.57
# 1      Land area below 5m (% of land area)     0        1         0.00
# 2      Land area below 5m (% of land area)     0        1         0.00
# ...

# %%
GDP_df=df.loc[df['Series name'] == "GDP ($)"]

# %%
GDP_df=GDP_df.loc[GDP_df['1990'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1991'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1992'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1993'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1994'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1995'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1996'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1997'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1998'] !=".."]
GDP_df=GDP_df.loc[GDP_df['1999'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2000'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2001'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2002'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2003'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2004'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2005'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2006'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2007'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2008'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2009'] !=".."]
GDP_df=GDP_df.loc[GDP_df['2010'] !=".."]
GDP_df.drop(['2011','SCALE','Decimals','Country code',"Series code","Series name"],axis=1,inplace=True)

# %%
temp=df
Pop_df=temp.loc[df['Series name'] == "Population"]
Pop_df.drop(['2011','SCALE','Decimals','Country code',"Series code","Series name"],axis=1,inplace=True)

# %%
GDP_df = GDP_df.set_index('Country name',drop=True)

# %%
Pop_df = Pop_df.set_index('Country name',drop=True)

# %%
test_df=GDP_df.merge(Pop_df,how='inner',left_index=True,right_index=True,suffixes=('_GDP','_Pop'))

# %%
test_df['1990_GDP_by_pop']=test_df['1990_GDP'].astype(float)/test_df['1990_Pop'].astype(float)
test_df['1991_GDP_by_pop']=test_df['1991_GDP'].astype(float)/test_df['1991_Pop'].astype(float)
test_df['1992_GDP_by_pop']=test_df['1992_GDP'].astype(float)/test_df['1992_Pop'].astype(float)
test_df['1993_GDP_by_pop']=test_df['1993_GDP'].astype(float)/test_df['1993_Pop'].astype(float)
test_df['1994_GDP_by_pop']=test_df['1994_GDP'].astype(float)/test_df['1994_Pop'].astype(float)
test_df['1995_GDP_by_pop']=test_df['1995_GDP'].astype(float)/test_df['1995_Pop'].astype(float)
test_df['1996_GDP_by_pop']=test_df['1996_GDP'].astype(float)/test_df['1996_Pop'].astype(float)
test_df['1997_GDP_by_pop']=test_df['1997_GDP'].astype(float)/test_df['1997_Pop'].astype(float)
test_df['1998_GDP_by_pop']=test_df['1998_GDP'].astype(float)/test_df['1998_Pop'].astype(float)
test_df['1999_GDP_by_pop']=test_df['1999_GDP'].astype(float)/test_df['1999_Pop'].astype(float)
test_df['2000_GDP_by_pop']=test_df['2000_GDP'].astype(float)/test_df['2000_Pop'].astype(float)
test_df['2001_GDP_by_pop']=test_df['2001_GDP'].astype(float)/test_df['2001_Pop'].astype(float)
test_df['2002_GDP_by_pop']=test_df['2002_GDP'].astype(float)/test_df['2002_Pop'].astype(float)
test_df['2003_GDP_by_pop']=test_df['2003_GDP'].astype(float)/test_df['2003_Pop'].astype(float)
test_df['2004_GDP_by_pop']=test_df['2004_GDP'].astype(float)/test_df['2004_Pop'].astype(float)
test_df['2005_GDP_by_pop']=test_df['2005_GDP'].astype(float)/test_df['2005_Pop'].astype(float)
test_df['2006_GDP_by_pop']=test_df['2006_GDP'].astype(float)/test_df['2006_Pop'].astype(float)
test_df['2007_GDP_by_pop']=test_df['2007_GDP'].astype(float)/test_df['2007_Pop'].astype(float)
test_df['2008_GDP_by_pop']=test_df['2008_GDP'].astype(float)/test_df['2008_Pop'].astype(float)
test_df['2009_GDP_by_pop']=test_df['2009_GDP'].astype(float)/test_df['2009_Pop'].astype(float)
test_df['2010_GDP_by_pop']=test_df['2010_GDP'].astype(float)/test_df['2010_Pop'].astype(float)

# %%
test_df.drop(['1990_GDP','1991_GDP','1992_GDP','1993_GDP','1994_GDP','1995_GDP','1996_GDP','1997_GDP','1998_GDP','1999_GDP','2000_GDP','2001_GDP','2002_GDP','2003_GDP','2004_GDP','2005_GDP','2006_GDP','2007_GDP','2008_GDP','2009_GDP','2010_GDP','1990_Pop','1991_Pop','1992_Pop','1993_Pop','1994_Pop','1995_Pop','1996_Pop','1997_Pop','1998_Pop','1999_Pop','2000_Pop','2001_Pop','2002_Pop','2003_Pop','2004_Pop','2005_Pop','2006_Pop','2007_Pop','2008_Pop','2009_Pop','2010_Pop'],axis=1)
# Out:
#                      1990_GDP_by_pop  1991_GDP_by_pop  1992_GDP_by_pop  \
# Country name
# Angola                    992.756820      1144.574971       525.260526
# Albania                   638.892178       346.072974       217.158330
# Argentina                4330.324573      5732.833843      6821.086043
# Armenia                   636.680690       588.979637       368.869465
# Antigua and Barbuda      6295.141048      6539.645272      6641.844385
# ...                              ...              ...              ...
# Samoa                     694.688969       688.649116       719.721643
# South Africa             3182.213788      3345.809343      3557.111166
# Congo, Dem. Rep.          256.817737       240.065363       208.048494
# Zambia                    418.366358       418.542802       384.746049
# Zimbabwe                  839.014919       803.992263       613.452878
#
#                      1993_GDP_by_pop  1994_GDP_by_pop  1995_GDP_by_pop  \
# Country name
# ...

# %%
test_df
# Out:
#                             1990_GDP         1991_GDP         1992_GDP  \
# Country name
# Angola                10260193360.68   12193746624.68    5779394291.76
# Albania                2101624960.00    1139166679.07     709452572.66
# Argentina            141352368714.69  189719989668.10  228779382768.15
# Armenia                2256838858.43    2068526521.90    1272577521.77
# Antigua and Barbuda     391570363.45     410388899.42     423762955.48
# ...                              ...              ...              ...
# Samoa                   112058888.22     111908235.97     117883207.85
# South Africa         112013925352.82  120225327665.39  130513036525.14
# Congo, Dem. Rep.       9349764580.35    9087965281.53    8206227134.01
# Zambia                 3288381745.33    3376791604.16    3182810919.62
# Zimbabwe               8783816665.90    8641481700.92    6751472200.86
#
#                             1993_GDP         1994_GDP         1995_GDP  \
# Country name
# ...

# %%
temp_2=df
CO2_df=temp_2.loc[df['Series name'] == "CO2 emissions, total (KtCO2)"]
CO2_df.drop(['2011','SCALE','Decimals','Country code',"Series code","Series name"],axis=1,inplace=True)
# Out:
# C:\Users\Oscar\.conda\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
CO2_df
# Out:
#           Country name       1990       1991       1992       1993       1994  \
# 1631             Aruba    1840.83    1928.84    1723.49    1771.16    1763.83
# 1632           Andorra         ..         ..         ..         ..         ..
# 1633       Afghanistan    2676.91    2493.56    1426.46    1375.13    1320.12
# 1634            Angola    4429.74    4367.40    4418.74    5801.19    3890.69
# 1635           Albania    7488.01    3971.36    2387.22    2343.21    1928.84
# ...                ...        ...        ...        ...        ...        ...
# 1859       Yemen, Rep.   -2999.61   10109.92   14381.97    9431.52   11367.70
# 1860      South Africa  333513.65  346337.15  324852.20  342549.14  358929.63
# 1861  Congo, Dem. Rep.    4070.37    3755.01    3619.33    3410.31    2478.89
# 1862            Zambia    2445.89    2416.55    2456.89    2500.89    2420.22
# 1863          Zimbabwe   15504.08   15823.11   16901.20   16208.14   17645.60
#
# ...

# %%
Pop_df
# Out:
#                          1990         1991         1992         1993  \
# Country name
# Aruba                62147.00     64642.00     68286.00     72573.00
# Andorra              52773.00     54996.00     57767.00     60670.00
# Afghanistan       19023678.00  19668810.29  20335820.34  21025450.09
# Angola            10335052.00  10653515.00  11002910.00  11371750.00
# Albania            3289483.00   3291695.00   3266983.00   3224901.00
# ...                       ...          ...          ...          ...
# Yemen, Rep.       11948209.00  12540234.00  13190192.00  13867656.00
# South Africa      35200000.00  35933107.76  36690738.76  37473796.40
# Congo, Dem. Rep.  36406226.00  37856212.00  39443819.00  41081774.00
# Zambia             7860053.00   8067972.00   8272498.00   8478471.00
# Zimbabwe          10469202.00  10748215.00  11005690.00  11244552.00
#
#                          1994         1995         1996         1997  \
# Country name
# ...

# %%
GDP_df
# Out:
#                                 1990             1991             1992  \
# Country name
# Angola                10260193360.68   12193746624.68    5779394291.76
# Albania                2101624960.00    1139166679.07     709452572.66
# Argentina            141352368714.69  189719989668.10  228779382768.15
# Armenia                2256838858.43    2068526521.90    1272577521.77
# Antigua and Barbuda     391570363.45     410388899.42     423762955.48
# ...                              ...              ...              ...
# Samoa                   112058888.22     111908235.97     117883207.85
# South Africa         112013925352.82  120225327665.39  130513036525.14
# Congo, Dem. Rep.       9349764580.35    9087965281.53    8206227134.01
# Zambia                 3288381745.33    3376791604.16    3182810919.62
# Zimbabwe               8783816665.90    8641481700.92    6751472200.86
#
#                                 1993             1994             1995  \
# Country name
# ...
